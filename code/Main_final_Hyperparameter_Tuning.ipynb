# %%
import os
import tensorflow as tf
from tensorflow.keras.applications import resnet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow import keras
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import glob
import numpy as np
import random
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import time
from datetime import datetime
from tensorflow.keras.regularizers import l2
from tensorflow.keras import optimizers



# Settings the warnings to be ignored
import warnings  
warnings.filterwarnings('ignore') 

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Variables
run = datetime.fromtimestamp(time.time()).strftime("%Y.%m.%d-%H%M")
optimizer = 'SGD'
scale = 100
batch_size = 16
epochs = 32
augumentation = 'No'
regularizer = 0.001
data = 'Updated'
grayscale = 'Yes'

# %%
if data == 'Original':

    training_dir = '../data/training'
    val_dir = '../data/validation'
    testing_dir = '../data/testing'

else:

    training_dir = '../data/updated_training'
    val_dir = '../data/updated_validation'
    testing_dir = '../data/updated_testing'

# %%
img_width, img_height = scale, scale

# %%
if augumentation == 'No':
    
    train_datagen = ImageDataGenerator(rescale=1./255)
    val_datagen = ImageDataGenerator(rescale=1./255)
    test_datagen = ImageDataGenerator(rescale=1./255)

else:
    train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
    )

    val_datagen = ImageDataGenerator(rescale=1./255)

    test_datagen = ImageDataGenerator(rescale=1./255)

# %%
if grayscale == 'No':
    color_channels = 3    
    train_generator = train_datagen.flow_from_directory(
        training_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42
    )

    val_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42
    )

    test_generator = test_datagen.flow_from_directory(
        testing_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42
    )

else:
    color_channels = 1
    train_generator = train_datagen.flow_from_directory(
        training_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        color_mode='grayscale',
        seed=42
    ) 
    
    val_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        color_mode='grayscale',
        seed=42
    )

    test_generator = test_datagen.flow_from_directory(
        testing_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        color_mode='grayscale',
        seed=42
    )
# Out:
# Found 1701 images belonging to 3 classes.
# Found 243 images belonging to 3 classes.
# Found 486 images belonging to 3 classes.

# %%
# Set seeds for reproducibility
SEED = 42
keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()
tf.random.set_seed(SEED)
initializer = tf.keras.initializers.GlorotUniform(seed=SEED)

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, color_channels),
kernel_regularizer=l2(regularizer), kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_regularizer=l2(regularizer), kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_regularizer=l2(regularizer), kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_regularizer=l2(regularizer), kernel_initializer=initializer))
model.add(Dropout(0.2))
# minor moderate and severe (3)
model.add(Dense(3, activation='softmax', kernel_regularizer=l2(regularizer), kernel_initializer=initializer))

# %%
model.compile(optimizer=optimizer,  loss='categorical_crossentropy', metrics=['accuracy', 'precision', 'recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 98, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,731,587 (6.61 MB)
#  Trainable params: 1,731,587 (6.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Set seeds for reproducibility
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()


# get the start time
st = time.time()

history = model.fit(train_generator, epochs=epochs, validation_data=val_generator)

# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
# Out:
# Epoch 1/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 16s 145ms/step - accuracy: 0.3295 - loss: 1.4982 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3333 - val_loss: 1.4832 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.3580 - loss: 1.4788 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.5021 - val_loss: 1.4732 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 145ms/step - accuracy: 0.4051 - loss: 1.4723 - precision: 0.0139 - recall: 1.6382e-05 - val_accuracy: 0.4609 - val_loss: 1.4543 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 128ms/step - accuracy: 0.4410 - loss: 1.4493 - precision: 0.4774 - recall: 0.0035 - val_accuracy: 0.5103 - val_loss: 1.4166 - val_precision: 0.6667 - val_recall: 0.0082
# Epoch 5/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.4766 - loss: 1.4050 - precision: 0.6881 - recall: 0.1012 - val_accuracy: 0.3539 - val_loss: 1.4993 - val_precision: 0.4519 - val_recall: 0.2510
# Epoch 6/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 16s 151ms/step - accuracy: 0.4752 - loss: 1.4001 - precision: 0.6373 - recall: 0.1760 - val_accuracy: 0.4897 - val_loss: 1.3618 - val_precision: 0.6292 - val_recall: 0.2305
# Epoch 7/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.5071 - loss: 1.3617 - precision: 0.6577 - recall: 0.2554 - val_accuracy: 0.5103 - val_loss: 1.3570 - val_precision: 0.6383 - val_recall: 0.2469
# Epoch 8/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.5468 - loss: 1.3357 - precision: 0.6426 - recall: 0.2866 - val_accuracy: 0.5638 - val_loss: 1.2836 - val_precision: 0.7241 - val_recall: 0.2593
# Epoch 9/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.5641 - loss: 1.3140 - precision: 0.6653 - recall: 0.3169 - val_accuracy: 0.5679 - val_loss: 1.2747 - val_precision: 0.7190 - val_recall: 0.3580
# Epoch 10/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.5297 - loss: 1.3211 - precision: 0.6273 - recall: 0.3312 - val_accuracy: 0.5638 - val_loss: 1.2636 - val_precision: 0.7250 - val_recall: 0.3580
# Epoch 11/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.5396 - loss: 1.3108 - precision: 0.6344 - recall: 0.3290 - val_accuracy: 0.5720 - val_loss: 1.2606 - val_precision: 0.7257 - val_recall: 0.3374
# Epoch 12/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.5495 - loss: 1.3013 - precision: 0.6706 - recall: 0.3476 - val_accuracy: 0.5761 - val_loss: 1.2512 - val_precision: 0.7434 - val_recall: 0.3457
# Epoch 13/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.5352 - loss: 1.3002 - precision: 0.6567 - recall: 0.3321 - val_accuracy: 0.5720 - val_loss: 1.2444 - val_precision: 0.7304 - val_recall: 0.3457
# Epoch 14/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 128ms/step - accuracy: 0.5549 - loss: 1.2935 - precision: 0.6596 - recall: 0.3530 - val_accuracy: 0.5844 - val_loss: 1.2365 - val_precision: 0.7132 - val_recall: 0.3992
# Epoch 15/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.5590 - loss: 1.2765 - precision: 0.6767 - recall: 0.3810 - val_accuracy: 0.5679 - val_loss: 1.2623 - val_precision: 0.6565 - val_recall: 0.3539
# Epoch 16/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.5596 - loss: 1.2688 - precision: 0.6549 - recall: 0.3663 - val_accuracy: 0.5802 - val_loss: 1.2476 - val_precision: 0.7500 - val_recall: 0.3210
# Epoch 17/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.5811 - loss: 1.2601 - precision: 0.6867 - recall: 0.3718 - val_accuracy: 0.5720 - val_loss: 1.2252 - val_precision: 0.6667 - val_recall: 0.4033
# Epoch 18/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.5743 - loss: 1.2535 - precision: 0.6920 - recall: 0.4212 - val_accuracy: 0.5638 - val_loss: 1.2225 - val_precision: 0.6901 - val_recall: 0.4033
# Epoch 19/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 125ms/step - accuracy: 0.5734 - loss: 1.2598 - precision: 0.6707 - recall: 0.3878 - val_accuracy: 0.5885 - val_loss: 1.2266 - val_precision: 0.7209 - val_recall: 0.3827
# Epoch 20/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 126ms/step - accuracy: 0.5810 - loss: 1.2317 - precision: 0.6663 - recall: 0.4009 - val_accuracy: 0.5679 - val_loss: 1.2269 - val_precision: 0.6857 - val_recall: 0.3951
# Epoch 21/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.5815 - loss: 1.2418 - precision: 0.6686 - recall: 0.3929 - val_accuracy: 0.5802 - val_loss: 1.2347 - val_precision: 0.6947 - val_recall: 0.3745
# Epoch 22/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.6085 - loss: 1.2057 - precision: 0.7126 - recall: 0.4398 - val_accuracy: 0.5021 - val_loss: 1.3035 - val_precision: 0.6541 - val_recall: 0.3580
# Epoch 23/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.5961 - loss: 1.2344 - precision: 0.6860 - recall: 0.4142 - val_accuracy: 0.5761 - val_loss: 1.2229 - val_precision: 0.6929 - val_recall: 0.3992
# Epoch 24/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - accuracy: 0.5977 - loss: 1.2183 - precision: 0.6965 - recall: 0.4301 - val_accuracy: 0.5226 - val_loss: 1.2494 - val_precision: 0.6383 - val_recall: 0.3704
# Epoch 25/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - accuracy: 0.6096 - loss: 1.1822 - precision: 0.6809 - recall: 0.4558 - val_accuracy: 0.5679 - val_loss: 1.2428 - val_precision: 0.6809 - val_recall: 0.3951
# Epoch 26/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - accuracy: 0.6147 - loss: 1.1895 - precision: 0.7061 - recall: 0.4481 - val_accuracy: 0.5597 - val_loss: 1.2344 - val_precision: 0.6552 - val_recall: 0.3909
# Epoch 27/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - accuracy: 0.6225 - loss: 1.1899 - precision: 0.6918 - recall: 0.4516 - val_accuracy: 0.5514 - val_loss: 1.2615 - val_precision: 0.6207 - val_recall: 0.3704
# Epoch 28/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - accuracy: 0.5990 - loss: 1.2053 - precision: 0.6799 - recall: 0.4421 - val_accuracy: 0.5350 - val_loss: 1.3257 - val_precision: 0.5688 - val_recall: 0.3745
# Epoch 29/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.6047 - loss: 1.2054 - precision: 0.6885 - recall: 0.4614 - val_accuracy: 0.5761 - val_loss: 1.2013 - val_precision: 0.6797 - val_recall: 0.4280
# Epoch 30/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.6404 - loss: 1.1616 - precision: 0.7325 - recall: 0.5032 - val_accuracy: 0.5720 - val_loss: 1.2196 - val_precision: 0.6525 - val_recall: 0.3786
# Epoch 31/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 115ms/step - accuracy: 0.6131 - loss: 1.1672 - precision: 0.6920 - recall: 0.4858 - val_accuracy: 0.5679 - val_loss: 1.2252 - val_precision: 0.6599 - val_recall: 0.3992
# Epoch 32/32
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 12s 116ms/step - accuracy: 0.6252 - loss: 1.1729 - precision: 0.6990 - recall: 0.4834 - val_accuracy: 0.5720 - val_loss: 1.2260 - val_precision: 0.6688 - val_recall: 0.4239

# %%
# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig(f'../images/{run}-loss.png', dpi=300)
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig(f'../images/{run}-accuracy.png', dpi=300)
plt.show()

# %%
train_images, train_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(train_generator)):
    images, labels = train_generator[i]
    train_images.extend(images)
    train_labels.extend(np.argmax(labels, axis=1))


train_images = np.array(train_images)
train_labels = np.array(train_labels)

predictions = model.predict(train_images)

y_pred = np.argmax(predictions, axis=1)
y_true = train_labels

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(cm, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45)
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe'])

ax.set_xlabel('Predicted Classes')
ax.set_ylabel('Actual Classes')

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, str(cm[i, j]), ha='center', va='center')


plt.title('Training Confusion Matrix')
plt.tight_layout()
plt.savefig(f'../images/{run}-training-cm.png', dpi=300)
plt.show()

train_report = classification_report(y_true, y_pred, target_names=class_names)
print('Training Classification Report:')
print(train_report)
# Out:
#  3/54 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 2024-12-02 22:22:22.457718: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2024-12-02 22:22:22.458187: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step
# Training Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.62      0.86      0.72       567
#  02-moderate       0.67      0.37      0.48       567
#    03-severe       0.70      0.72      0.71       567
#
#     accuracy                           0.65      1701
#    macro avg       0.66      0.65      0.64      1701
# weighted avg       0.66      0.65      0.64      1701

# %%
test_images, test_labels = [], []
class_names = sorted(test_generator.class_indices.keys())
for i in range(len(test_generator)):
    images, labels = test_generator[i]
    test_images.extend(images)
    test_labels.extend(np.argmax(labels, axis=1))


test_images = np.array(test_images)
test_labels = np.array(test_labels)

predictions = model.predict(test_images)

y_pred = np.argmax(predictions, axis=1)
y_true = test_labels

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(cm, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45)
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe'])

ax.set_xlabel('Predicted Classes')
ax.set_ylabel('Actual Classes')

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, str(cm[i, j]), ha='center', va='center')

plt.title('Testing Confusion Matrix')
plt.tight_layout()
plt.savefig(f'../images/{run}-testing-cm.png', dpi=300)
plt.show()

test_report = classification_report(y_true, y_pred, target_names=class_names)
print('testing Classification Report:')
print(test_report)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# testing Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.59      0.84      0.69       162
#  02-moderate       0.48      0.26      0.34       162
#    03-severe       0.60      0.62      0.61       162
#
#     accuracy                           0.57       486
#    macro avg       0.56      0.57      0.55       486
# weighted avg       0.56      0.57      0.55       486

# %%
result = pd.DataFrame.from_dict(history.history).tail(1)
result['F1_Score'] = ((2 * result['precision'] * result['recall']) / (result['precision'] + result['recall']))
result['val_F1_Score'] = ((2 * result['val_precision'] * result['val_recall']) / (result['val_precision'] + result['val_recall']))

result['Optimizer'] = optimizer
result['Epochs'] = epochs
result['Batch_Size'] = batch_size
result['Rescale'] = scale
result['Time(min)'] = elapsed_time/60
result['Run'] = run
result['Regularizer(L2)'] = regularizer
result['Augumentation'] = augumentation
result['Data'] = data
result['Grayscale'] = grayscale

columns = ['Run','Time(min)','Optimizer','Epochs','Batch_Size','Rescale','Regularizer(L2)','Data', 'Grayscale',
           'Augumentation','accuracy','loss','precision','recall','F1_Score', 'val_accuracy', 
           'val_loss','val_precision','val_recall','val_F1_Score']

result = result.reindex(columns=columns).reset_index(drop=True)

result
# Out:
#                Run  Time(min) Optimizer  Epochs  Batch_Size  Rescale  \
# 0  2024.12.02-2215   7.221078       SGD      32          16      100
#
#    Regularizer(L2)     Data Grayscale Augumentation  accuracy      loss  \
# 0            0.001  Updated       Yes            No   0.60729  1.172646
#
#    precision    recall  F1_Score  val_accuracy  val_loss  val_precision  \
# 0   0.688301  0.473839  0.561281      0.572016   1.22596       0.668831
#
#    val_recall  val_F1_Score
# 0    0.423868      0.518892

# %%
# Load the existing CSV file into a DataFrame
existing_df = pd.read_csv('results.csv')

# Append the new DataFrame to the existing one
combined_df = pd.concat([existing_df, result], ignore_index=True)

# Save the updated DataFrame back to the same CSV file
combined_df.to_csv('results.csv', index=False)

# %%
combined_df
# Out:
#                 Run  Time(min) Optimizer  Epochs  Batch_Size  Rescale  \
# 0   2024.11.20-2009   7.810579       SGD      32          16      100
# 1   2024.11.17-2200   7.309321       SGD      50          32      100
# 2   2024.11.17-1222   2.771039       SGD      32          32      100
# 3   2024.11.18-2125   9.404231       SGD      50          32      100
# 4   2024.11.23-1239  14.158290       SGD      32          16      100
# 5   2024.11.17-1215   2.763423      adam      32          32      100
# 6   2024.11.18-2136   9.698446       SGD      50          32      100
# 7   2024.11.18-2049  10.003794       SGD      50          32      100
# 8   2024.11.20-1918   9.190498       SGD      50          16      100
# 9   2024.11.17-1056   6.005655      adam      32          32      100
# 10  2024.11.23-1338   6.626290       SGD      32          16      100
# 11  2024.11.20-2032   8.152645       SGD      32          16      100
# 12  2024.11.18-2114   9.872158       SGD      50          32      100
# 13  2024.11.20-2023   5.559539       SGD      32          16       75
# 14  2024.11.19-2008   5.037192       SGD      50          16      100
# 15  2024.11.17-1018  15.264399      adam      32          32      150
# 16  2024.11.18-2102  10.161397       SGD      50          32      100
# 17  2024.11.17-1230   4.268351       SGD      50          32      100
# 18  2024.11.17-1237   2.906627       SGD      32          32      100
# 19  2024.11.17-2145   5.041412       SGD      32          32      100
# 20  2024.11.19-2014   4.351204       SGD      50          64      100
# 21  2024.11.18-1858   8.929252      Adam      50          32      100
# 22  2024.11.17-1226   3.455672       SGD      32          32      100
# 23  2024.11.17-2152   4.775904       SGD      32          32      100
# 24  2024.11.17-1124  43.435671      adam      32          32      200
# 25  2024.12.02-2215   7.221078       SGD      32          16      100
#
#    Regularizer(L2)      Data Augumentation Grayscale  ...      loss  \
# 0              NaN  Original            No       Yes  ...  2.241912
# 1            0.001  Original            No       Yes  ...  1.150984
# 2              NaN  Original            No        No  ...  3.185605
# 3              NaN   Updated            No       Yes  ...  2.226537
# 4             0.01   Updated            No       Yes  ...  1.369934
# 5              NaN  Original            No        No  ...  0.982818
# 6              NaN   Updated            No        No  ...  2.207097
# 7            0.001   Updated           Yes       Yes  ...  1.279316
# 8              NaN  Original            No       Yes  ...  1.595863
# 9              NaN  Original           Yes        No  ...  1.017572
# 10            0.01   Updated            No       Yes  ...  1.926308
# 11             NaN   Updated            No       Yes  ...  1.926308
# 12           0.001   Updated            No        No  ...  1.013282
# 13             NaN   Updated            No       Yes  ...  1.933935
# 14             NaN  Original            No       Yes  ...  1.603343
# 15               -  Original           Yes        No  ...  1.031323
# 16             NaN   Updated           Yes       Yes  ...  2.309755
# 17             NaN  Original            No        No  ...  2.545763
# 18           0.001  Original            No        No  ...  1.195060
# 19           0.001  Original            No       Yes  ...  1.228024
# 20             NaN  Original            No       Yes  ...  3.433272
# 21           0.001  Original            No        No  ...  0.464573
# 22             NaN  Original           Yes        No  ...  3.271136
# 23             NaN  Original            No       Yes  ...  3.182032
# 24             NaN  Original           Yes        No  ...  1.127053
# 25           0.001   Updated            No       Yes  ...  1.172646
#
#     precision    recall  F1_Score  val_accuracy  val_loss  val_precision  \
# 0    0.665521  0.425641  0.519214      0.617021  2.189133       0.773438
# 1    0.709000  0.519414  0.599577      0.608511  1.211403       0.683544
# 2    0.671982  0.432234  0.526081      0.591489  3.188465       0.741071
# 3    0.704291  0.443857  0.544537      0.588477  2.236971       0.662577
# 4    0.662461  0.370370  0.475113      0.588477  1.324985       0.655629
# 5    0.676630  0.364835  0.474060      0.587234  0.950834       0.730159
# 6    0.716724  0.493827  0.584755      0.584362  2.259890       0.647799
# 7    0.667920  0.313345  0.426571      0.584362  1.203535       0.704225
# 8    0.696502  0.495971  0.579375      0.582979  1.663156       0.679739
# 9    0.631957  0.257875  0.366285      0.582979  0.981662       0.742574
# 10   0.687970  0.430335  0.529476      0.580247  1.911914       0.681818
# 11   0.687970  0.430335  0.529476      0.580247  1.911914       0.681818
# 12   0.770922  0.639036  0.698811      0.576132  1.221429       0.635870
# 13   0.675926  0.386243  0.491582      0.576132  1.882702       0.682432
# 14   0.696970  0.488645  0.574505      0.574468  1.658819       0.642424
# 15   0.663004  0.265201  0.378859      0.574468  0.973182       0.800000
# 16   0.662864  0.307466  0.420080      0.572016  2.213629       0.713235
# 17   0.697576  0.484982  0.572169      0.565957  2.617812       0.634615
# 18   0.685089  0.481319  0.565404      0.565957  1.248862       0.737288
# 19   0.667028  0.450549  0.537822      0.565957  1.259151       0.702290
# 20   0.659873  0.379487  0.481860      0.557447  3.433070       0.698276
# 21   0.928465  0.912821  0.920576      0.548936  1.883912       0.560538
# 22   0.654369  0.246886  0.358511      0.548936  3.212124       0.773810
# 23   0.662413  0.418315  0.512797      0.536170  3.205369       0.672131
# 24   0.000000  0.000000       NaN      0.268085  1.140526       0.000000
# 25   0.688301  0.473839  0.561281      0.572016  1.225960       0.668831
#
#     val_recall  val_F1_Score  \
# 0     0.421277      0.545455
# 1     0.459574      0.549618
# 2     0.353191      0.478386
# 3     0.444444      0.532020
# 4     0.407407      0.502538
# 5     0.391489      0.509695
# 6     0.423868      0.512438
# 7     0.411523      0.519481
# 8     0.442553      0.536082
# 9     0.319149      0.446429
# 10    0.432099      0.528967
# 11    0.432099      0.528967
# 12    0.481481      0.548009
# 13    0.415638      0.516624
# 14    0.451064      0.530000
# 15    0.306383      0.443077
# 16    0.399177      0.511873
# 17    0.421277      0.506394
# 18    0.370213      0.492918
# 19    0.391489      0.502732
# 20    0.344681      0.461538
# 21    0.531915      0.545852
# 22    0.276596      0.407524
# 23    0.348936      0.459384
# 24    0.000000           NaN
# 25    0.423868      0.518892
#
#                                           Unnamed: 20
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   flipped architecture (128, 64, 32, 16, 3 neurons)
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                      Momentum added
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
# [26 rows x 21 columns]
