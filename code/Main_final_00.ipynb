# %%
import os
import tensorflow as tf
from tensorflow.keras.applications import resnet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow import keras
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import glob
import numpy as np
import random
from sklearn import preprocessing
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import time
from datetime import datetime



# Settings the warnings to be ignored
import warnings  
warnings.filterwarnings('ignore')

# %%
training_dir = '../data/training'
val_dir = '../data/validation'
testing_dir = '../data/testing'

# %%
optimizer = 'SGD'
scale = 100
batch_size = 32
epochs = 32
run = datetime.fromtimestamp(time.time()).strftime("%Y.%m.%d-%H%M")

# %%
img_width, img_height = scale, scale

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    training_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    seed=42
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    testing_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    seed=42
)
# Out:
# Found 1365 images belonging to 3 classes.
# Found 235 images belonging to 3 classes.
# Found 235 images belonging to 3 classes.

# %%
# Set seeds for reproducibility
SEED = 42
keras.utils.set_random_seed(SEED)
tf.config.experimental.enable_op_determinism()
tf.random.set_seed(SEED)
initializer = tf.keras.initializers.GlorotUniform(seed=SEED)



model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3), kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=initializer))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu', kernel_initializer=initializer))
model.add(Dropout(0.5))
# minor moderate and severe (3)
model.add(Dense(3, activation='softmax', kernel_initializer=initializer))

# %%
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy', 'precision', 'recall'])

# %%
# Set seeds for reproducibility
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()


# get the start time
st = time.time()

history = model.fit(train_generator, epochs=epochs, validation_data=val_generator)

# get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
# Out:
# Epoch 1/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.3462 - loss: 1.1010 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2638 - val_loss: 1.1069 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.3155 - loss: 1.1044 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2681 - val_loss: 1.1172 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.3584 - loss: 1.0946 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3277 - val_loss: 1.0943 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.3690 - loss: 1.0908 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2809 - val_loss: 1.0991 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.3588 - loss: 1.0906 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.2681 - val_loss: 1.1050 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.3867 - loss: 1.0878 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.3532 - val_loss: 1.0852 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.4277 - loss: 1.0726 - precision: 0.1136 - recall: 8.5728e-05 - val_accuracy: 0.3574 - val_loss: 1.0772 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.3759 - loss: 1.0801 - precision: 0.1439 - recall: 1.6226e-04 - val_accuracy: 0.2894 - val_loss: 1.0869 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.4224 - loss: 1.0664 - precision: 0.3746 - recall: 0.0027 - val_accuracy: 0.4085 - val_loss: 1.0789 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.4201 - loss: 1.0598 - precision: 0.5567 - recall: 0.0036 - val_accuracy: 0.3489 - val_loss: 1.0834 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.4433 - loss: 1.0588 - precision: 0.5353 - recall: 0.0072 - val_accuracy: 0.4851 - val_loss: 1.0332 - val_precision: 1.0000 - val_recall: 0.0085
# Epoch 12/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4467 - loss: 1.0495 - precision: 0.6689 - recall: 0.0365 - val_accuracy: 0.4298 - val_loss: 1.0303 - val_precision: 1.0000 - val_recall: 0.0128
# Epoch 13/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.4432 - loss: 1.0509 - precision: 0.5990 - recall: 0.0302 - val_accuracy: 0.5064 - val_loss: 1.0119 - val_precision: 1.0000 - val_recall: 0.0681
# Epoch 14/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.4206 - loss: 1.0434 - precision: 0.5996 - recall: 0.0283 - val_accuracy: 0.4681 - val_loss: 1.0225 - val_precision: 1.0000 - val_recall: 0.0170
# Epoch 15/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.4461 - loss: 1.0254 - precision: 0.6907 - recall: 0.0437 - val_accuracy: 0.4213 - val_loss: 1.0382 - val_precision: 0.7143 - val_recall: 0.1064
# Epoch 16/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4407 - loss: 1.0507 - precision: 0.5420 - recall: 0.0777 - val_accuracy: 0.4511 - val_loss: 1.0385 - val_precision: 0.7838 - val_recall: 0.2468
# Epoch 17/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4536 - loss: 1.0412 - precision: 0.5716 - recall: 0.0913 - val_accuracy: 0.4638 - val_loss: 1.0095 - val_precision: 0.8049 - val_recall: 0.1404
# Epoch 18/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.4986 - loss: 1.0093 - precision: 0.6352 - recall: 0.1156 - val_accuracy: 0.5362 - val_loss: 0.9625 - val_precision: 0.8919 - val_recall: 0.1404
# Epoch 19/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4477 - loss: 1.0179 - precision: 0.5781 - recall: 0.1209 - val_accuracy: 0.5787 - val_loss: 0.9528 - val_precision: 0.9302 - val_recall: 0.1702
# Epoch 20/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.4874 - loss: 0.9916 - precision: 0.6611 - recall: 0.1480 - val_accuracy: 0.4255 - val_loss: 1.0713 - val_precision: 0.5739 - val_recall: 0.2809
# Epoch 21/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.4791 - loss: 1.0080 - precision: 0.6517 - recall: 0.1725 - val_accuracy: 0.5277 - val_loss: 0.9623 - val_precision: 0.8333 - val_recall: 0.1702
# Epoch 22/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.5072 - loss: 0.9891 - precision: 0.6979 - recall: 0.1864 - val_accuracy: 0.4936 - val_loss: 0.9780 - val_precision: 0.7705 - val_recall: 0.2000
# Epoch 23/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.5054 - loss: 0.9995 - precision: 0.6509 - recall: 0.1522 - val_accuracy: 0.4213 - val_loss: 1.0706 - val_precision: 0.6017 - val_recall: 0.3021
# Epoch 24/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.4761 - loss: 1.0098 - precision: 0.6018 - recall: 0.1833 - val_accuracy: 0.4936 - val_loss: 0.9846 - val_precision: 0.6962 - val_recall: 0.2340
# Epoch 25/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4758 - loss: 0.9776 - precision: 0.7130 - recall: 0.1732 - val_accuracy: 0.4766 - val_loss: 0.9931 - val_precision: 0.6800 - val_recall: 0.2894
# Epoch 26/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.5035 - loss: 0.9930 - precision: 0.6228 - recall: 0.1830 - val_accuracy: 0.5404 - val_loss: 0.9495 - val_precision: 0.8305 - val_recall: 0.2085
# Epoch 27/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.4677 - loss: 0.9849 - precision: 0.7066 - recall: 0.1859 - val_accuracy: 0.5574 - val_loss: 0.9304 - val_precision: 0.7363 - val_recall: 0.2851
# Epoch 28/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.4794 - loss: 1.0065 - precision: 0.5767 - recall: 0.2033 - val_accuracy: 0.5021 - val_loss: 0.9675 - val_precision: 0.7403 - val_recall: 0.2426
# Epoch 29/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.5140 - loss: 0.9559 - precision: 0.7310 - recall: 0.2080 - val_accuracy: 0.5532 - val_loss: 0.9162 - val_precision: 0.8000 - val_recall: 0.2723
# Epoch 30/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.5247 - loss: 0.9763 - precision: 0.6485 - recall: 0.2341 - val_accuracy: 0.4638 - val_loss: 0.9956 - val_precision: 0.6667 - val_recall: 0.2723
# Epoch 31/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.4685 - loss: 0.9839 - precision: 0.6438 - recall: 0.1996 - val_accuracy: 0.4894 - val_loss: 0.9797 - val_precision: 0.6379 - val_recall: 0.3149
# Epoch 32/32
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.5181 - loss: 0.9771 - precision: 0.6748 - recall: 0.2424 - val_accuracy: 0.5191 - val_loss: 0.9533 - val_precision: 0.7234 - val_recall: 0.2894

# %%
# loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.savefig(f'../images/{run}-loss.png', dpi=300)
plt.show()

# accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.savefig(f'../images/{run}-accuracy.png', dpi=300)
plt.show()

# %%
train_images, train_labels = [], []
class_names = sorted(train_generator.class_indices.keys())
for i in range(len(train_generator)):
    images, labels = train_generator[i]
    train_images.extend(images)
    train_labels.extend(np.argmax(labels, axis=1))


train_images = np.array(train_images)
train_labels = np.array(train_labels)

predictions = model.predict(train_images)

y_pred = np.argmax(predictions, axis=1)
y_true = train_labels

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(cm, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45)
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe'])

ax.set_xlabel('Predicted Classes')
ax.set_ylabel('Actual Classes')

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, str(cm[i, j]), ha='center', va='center')


plt.title('Training Confusion Matrix')
plt.tight_layout()
plt.savefig(f'../images/{run}-training-cm.png', dpi=300)
plt.show()

train_report = classification_report(y_true, y_pred, target_names=class_names)
print('Training Classification Report:')
print(train_report)
# Out:
#  5/43 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 2024-11-16 19:53:47.168417: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 2024-11-16 19:53:47.168756: E tensorflow/core/framework/node_def_util.cc:676] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Training Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.62      0.56      0.59       439
#  02-moderate       0.42      0.53      0.47       502
#    03-severe       0.59      0.47      0.52       424
#
#     accuracy                           0.52      1365
#    macro avg       0.54      0.52      0.53      1365
# weighted avg       0.54      0.52      0.52      1365

# %%
test_images, test_labels = [], []
class_names = sorted(test_generator.class_indices.keys())
for i in range(len(test_generator)):
    images, labels = test_generator[i]
    test_images.extend(images)
    test_labels.extend(np.argmax(labels, axis=1))


test_images = np.array(test_images)
test_labels = np.array(test_labels)

predictions = model.predict(test_images)

y_pred = np.argmax(predictions, axis=1)
y_true = test_labels

cm = confusion_matrix(y_true, y_pred)
fig, ax = plt.subplots()
cax = ax.matshow(cm, cmap='Reds')

cbar = fig.colorbar(cax)

ax.set_xticklabels([''] + ['minor', 'moderate', 'severe'], rotation=45)
ax.set_yticklabels([''] + ['minor', 'moderate', 'severe'])

ax.set_xlabel('Predicted Classes')
ax.set_ylabel('Actual Classes')

for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, str(cm[i, j]), ha='center', va='center')

plt.title('Testing Confusion Matrix')
plt.tight_layout()
plt.savefig(f'../images/{run}-testing-cm.png', dpi=300)
plt.show()

test_report = classification_report(y_true, y_pred, target_names=class_names)
print('testing Classification Report:')
print(test_report)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# testing Classification Report:
#               precision    recall  f1-score   support
#
#     01-minor       0.92      0.39      0.55        90
#  02-moderate       0.30      0.41      0.35        63
#    03-severe       0.55      0.74      0.63        82
#
#     accuracy                           0.52       235
#    macro avg       0.59      0.52      0.51       235
# weighted avg       0.63      0.52      0.52       235

# %%
result = pd.DataFrame.from_dict(history.history).tail(1)
result['F1_Score'] = ((2 * result['precision'] * result['recall']) / (result['precision'] + result['recall']))
result['val_F1_Score'] = ((2 * result['val_precision'] * result['val_recall']) / (result['val_precision'] + result['val_recall']))

result['Optimizer'] = optimizer
result['Epochs'] = epochs
result['Batch_Size'] = batch_size
result['Rescale'] = scale
result['time(min)'] = elapsed_time/60
result['run'] = run

columns = ['run','time(min)','Optimizer','Epochs','Batch_Size','Rescale',
           'accuracy','loss','precision','recall','F1_Score','val_accuracy', 
           'val_loss','val_precision','val_recall','val_F1_Score']

result = result.reindex(columns=columns).reset_index(drop=True)

result
# Out:
#                run  time(min) Optimizer  Epochs  Batch_Size  Rescale  \
# 0  2024.11.16-1950   3.234585       SGD      32          32      100
#
#    accuracy      loss  precision    recall  F1_Score  val_accuracy  val_loss  \
# 0  0.520879  0.982809   0.642702  0.216117  0.323465      0.519149  0.953263
#
#    val_precision  val_recall  val_F1_Score
# 0       0.723404    0.289362      0.413374

# %%
# Load the existing CSV file into a DataFrame
existing_df = pd.read_csv('results.csv')

# Append the new DataFrame to the existing one
combined_df = pd.concat([existing_df, result], ignore_index=True)

# Save the updated DataFrame back to the same CSV file
combined_df.to_csv('results.csv', index=False)

# %%
combined_df
# Out:
#                run  time(min) Optimizer  Epochs  Batch_Size  Rescale  \
# 0  2024.11.16-1820   6.963402      adam      16          32      150
# 1  2024.11.16-1847  15.477021      adam      32          32      150
# 2  2024.11.16-1853  12.358927      adam      50          32      150
# 3  2024.11.16-1930   7.113925       SGD      32          32      150
# 4  2024.11.16-1946   3.294831      adam      32          32      100
# 5  2024.11.16-1950   3.234585       SGD      32          32      100
#
#    accuracy      loss  precision    recall  F1_Score  val_accuracy  val_loss  \
# 0  0.553114  0.932718   0.646875  0.303297  0.412968      0.553191  0.901792
# 1  0.610989  0.848950   0.691176  0.413187  0.517194      0.600000  0.813652
# 2  0.608059  0.837329   0.670188  0.418315  0.515111      0.621277  0.784865
# 3  0.517949  0.965647   0.650307  0.232967  0.343042      0.548936  0.920503
# 4  0.596337  0.847244   0.694482  0.378022  0.489564      0.570213  0.829275
# 5  0.520879  0.982809   0.642702  0.216117  0.323465      0.519149  0.953263
#
#    val_precision  val_recall  val_F1_Score
# 0       0.715517    0.353191      0.472934
# 1       0.627551    0.523404      0.570766
# 2       0.688623    0.489362      0.572139
# 3       0.736842    0.297872      0.424242
# 4       0.651934    0.502128      0.567308
# 5       0.723404    0.289362      0.413374
